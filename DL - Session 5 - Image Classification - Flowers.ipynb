# %% [markdown]
# ### Load tensorflow

# %%
import tensorflow as tf
tf.reset_default_graph()
tf.set_random_seed(42)

# %% [markdown]
# ### Read training and test data

# %%
import pandas as pd
train_df = pd.read_csv('data/flower_photos/train.csv')
test_df = pd.read_csv('data/flower_photos/test.csv')

# %%
#Get class names
class_names = train_df['class'].unique().tolist()
print('Flower classes: ', class_names)
# Out:
# Flower classes:  ['tulips', 'daisy', 'sunflowers', 'dandelion', 'roses']

# %%
#Define some parameters
img_size = 60
img_depth = 3

# %% [markdown]
# ### Build batch generator

# %%
import numpy as np

# %%
def batch_generator(df, batchsize=32):   
    
    while True:       
                
        #Generate random numbers to pick images from dataset
        batch_nums = np.random.randint(0,df.shape[0], batchsize)
        
        #Initialize batch images array
        batch_images = np.zeros((batchsize,img_size, img_size,img_depth))
        
        #Initiate batch label array
        batch_labels = np.zeros((batchsize, len(class_names)))
        
        for i in range(batchsize):
            
            #Load image
            flower_image =  tf.keras.preprocessing.image.load_img('data/' + 
                                                                  df.loc[batch_nums[i]]['image_file'],
                                                                  target_size=(img_size, img_size))
            #Convert to array
            flower_image = tf.keras.preprocessing.image.img_to_array(flower_image)
            
            #Get the class
            img_class = df.loc[batch_nums[i]]['class']
            #Conver class to number
            img_class = class_names.index(img_class)
            #Convert class to one hot encoding
            img_class = tf.keras.utils.to_categorical(img_class, num_classes=len(class_names))
            
            #Update batch images and class arrays
            batch_images[i] = flower_image
            batch_labels[i] = img_class        
        
        yield batch_images, batch_labels

# %% [markdown]
# ### Build CNN Model

# %%
#Initialize model, reshape & normalize data
model = tf.keras.models.Sequential()

#Add Layers
model.add(tf.keras.layers.BatchNormalization(input_shape=(img_size,img_size,3,)))
model.add(tf.keras.layers.Conv2D(32, kernel_size=(3,3), activation='relu'))
model.add(tf.keras.layers.Conv2D(64, kernel_size=(3,3), activation='relu'))
model.add(tf.keras.layers.MaxPool2D(pool_size=(2,2)))
model.add(tf.keras.layers.Flatten())
model.add(tf.keras.layers.Dense(128, activation='relu'))
model.add(tf.keras.layers.Dropout(0.25))
model.add(tf.keras.layers.Dense(len(class_names), activation='softmax'))

# %%
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %% [markdown]
# ### Train the model

# %%
#Create train and test generator
batchsize = 64
train_generator = batch_generator(train_df, batchsize=batchsize) #batchsize can be changed
test_generator = batch_generator(test_df, batchsize=batchsize)

# %%
model.fit_generator(train_generator, 
                          epochs=50,
                          steps_per_epoch= train_df.shape[0]//batchsize,
                          validation_data=test_generator,
                          validation_steps = test_df.shape[0]//batchsize)
# Out:
# Epoch 1/50
# 45/45 [==============================] - 16s 345ms/step - loss: 2.0044 - acc: 0.3118 - val_loss: 1.4147 - val_acc: 0.3452
# Epoch 2/50
# 45/45 [==============================] - 12s 272ms/step - loss: 1.3489 - acc: 0.4472 - val_loss: 1.4356 - val_acc: 0.4290
# Epoch 3/50
# 45/45 [==============================] - 12s 274ms/step - loss: 1.1085 - acc: 0.5583 - val_loss: 1.1159 - val_acc: 0.5426
# Epoch 4/50
# 45/45 [==============================] - 12s 275ms/step - loss: 0.8277 - acc: 0.6875 - val_loss: 1.1824 - val_acc: 0.5540
# Epoch 5/50
# 45/45 [==============================] - 12s 274ms/step - loss: 0.6200 - acc: 0.7892 - val_loss: 1.0731 - val_acc: 0.5980
# Epoch 6/50
# 45/45 [==============================] - 12s 273ms/step - loss: 0.4017 - acc: 0.8705 - val_loss: 1.1696 - val_acc: 0.5753
# Epoch 7/50
# 45/45 [==============================] - 12s 273ms/step - loss: 0.2540 - acc: 0.9302 - val_loss: 1.3268 - val_acc: 0.5767
# Epoch 8/50
# 45/45 [==============================] - 12s 271ms/step - loss: 0.1639 - acc: 0.9562 - val_loss: 1.4762 - val_acc: 0.5795
# Epoch 9/50
# 45/45 [==============================] - 12s 273ms/step - loss: 0.0910 - acc: 0.9781 - val_loss: 1.4416 - val_acc: 0.5994
# Epoch 10/50
# 45/45 [==============================] - 12s 271ms/step - loss: 0.0679 - acc: 0.9833 - val_loss: 1.6730 - val_acc: 0.5582
# Epoch 11/50
# 45/45 [==============================] - 12s 270ms/step - loss: 0.0566 - acc: 0.9875 - val_loss: 1.7406 - val_acc: 0.5554
# Epoch 12/50
# 45/45 [==============================] - 12s 272ms/step - loss: 0.0449 - acc: 0.9903 - val_loss: 1.8459 - val_acc: 0.5923
# Epoch 13/50
# 45/45 [==============================] - 12s 274ms/step - loss: 0.0362 - acc: 0.9899 - val_loss: 2.0534 - val_acc: 0.5483
# Epoch 14/50
# 45/45 [==============================] - 12s 277ms/step - loss: 0.0351 - acc: 0.9938 - val_loss: 2.0113 - val_acc: 0.5824
# Epoch 15/50
# 45/45 [==============================] - 12s 273ms/step - loss: 0.0221 - acc: 0.9969 - val_loss: 2.1016 - val_acc: 0.5540
# Epoch 16/50
# 45/45 [==============================] - 12s 276ms/step - loss: 0.0132 - acc: 0.9976 - val_loss: 2.0052 - val_acc: 0.5923
# Epoch 17/50
# 45/45 [==============================] - 12s 276ms/step - loss: 0.0129 - acc: 0.9986 - val_loss: 2.3095 - val_acc: 0.5682
# Epoch 18/50
# 45/45 [==============================] - 12s 273ms/step - loss: 0.0153 - acc: 0.9962 - val_loss: 2.2051 - val_acc: 0.5767
# Epoch 19/50
# 45/45 [==============================] - 12s 275ms/step - loss: 0.0148 - acc: 0.9976 - val_loss: 2.1857 - val_acc: 0.6023
# Epoch 20/50
# 45/45 [==============================] - 12s 270ms/step - loss: 0.0085 - acc: 0.9990 - val_loss: 2.1237 - val_acc: 0.5881
# Epoch 21/50
# 45/45 [==============================] - 12s 273ms/step - loss: 0.0164 - acc: 0.9944 - val_loss: 1.9932 - val_acc: 0.5767
# Epoch 22/50
# 45/45 [==============================] - 12s 273ms/step - loss: 0.0111 - acc: 0.9976 - val_loss: 2.2951 - val_acc: 0.5739
# Epoch 23/50
# 45/45 [==============================] - 12s 272ms/step - loss: 0.0077 - acc: 0.9990 - val_loss: 2.3272 - val_acc: 0.5895
# Epoch 24/50
# 45/45 [==============================] - 12s 272ms/step - loss: 0.0164 - acc: 0.9951 - val_loss: 2.0950 - val_acc: 0.6065
# Epoch 25/50
# 45/45 [==============================] - 12s 270ms/step - loss: 0.0090 - acc: 0.9976 - val_loss: 2.3941 - val_acc: 0.5767
# Epoch 26/50
# 45/45 [==============================] - 12s 272ms/step - loss: 0.0126 - acc: 0.9972 - val_loss: 2.2021 - val_acc: 0.5597
# Epoch 27/50
# 45/45 [==============================] - 12s 270ms/step - loss: 0.0067 - acc: 0.9990 - val_loss: 2.3625 - val_acc: 0.5739
# Epoch 28/50
# 45/45 [==============================] - 12s 273ms/step - loss: 0.0079 - acc: 0.9976 - val_loss: 2.5688 - val_acc: 0.5824
# Epoch 29/50
# 45/45 [==============================] - 12s 276ms/step - loss: 0.0150 - acc: 0.9948 - val_loss: 2.1187 - val_acc: 0.5710
# Epoch 30/50
# 45/45 [==============================] - 12s 273ms/step - loss: 0.0170 - acc: 0.9955 - val_loss: 2.3657 - val_acc: 0.5938
# Epoch 31/50
# 45/45 [==============================] - 12s 274ms/step - loss: 0.0100 - acc: 0.9983 - val_loss: 2.3284 - val_acc: 0.5852
# Epoch 32/50
# 45/45 [==============================] - 12s 272ms/step - loss: 0.0083 - acc: 0.9979 - val_loss: 2.9045 - val_acc: 0.5540
# Epoch 33/50
# 45/45 [==============================] - 12s 273ms/step - loss: 0.0065 - acc: 0.9976 - val_loss: 2.1235 - val_acc: 0.5938
# Epoch 34/50
# 45/45 [==============================] - 12s 273ms/step - loss: 0.0114 - acc: 0.9962 - val_loss: 2.4571 - val_acc: 0.5625
# Epoch 35/50
# 45/45 [==============================] - 12s 273ms/step - loss: 0.0058 - acc: 0.9976 - val_loss: 2.5900 - val_acc: 0.5554
# Epoch 36/50
# 45/45 [==============================] - 12s 273ms/step - loss: 0.0033 - acc: 0.9986 - val_loss: 2.9582 - val_acc: 0.5767
# Epoch 37/50
# 45/45 [==============================] - 12s 274ms/step - loss: 0.0025 - acc: 0.9993 - val_loss: 2.8894 - val_acc: 0.5767
# Epoch 38/50
# 45/45 [==============================] - 12s 273ms/step - loss: 0.0026 - acc: 0.9990 - val_loss: 2.9212 - val_acc: 0.5582
# Epoch 39/50
# 45/45 [==============================] - 12s 274ms/step - loss: 0.0040 - acc: 0.9986 - val_loss: 2.8183 - val_acc: 0.5724
# Epoch 40/50
# 45/45 [==============================] - 12s 273ms/step - loss: 0.0038 - acc: 0.9990 - val_loss: 2.9379 - val_acc: 0.5710
# Epoch 41/50
# 45/45 [==============================] - 12s 277ms/step - loss: 0.0094 - acc: 0.9983 - val_loss: 3.0354 - val_acc: 0.5739
# Epoch 42/50
# 45/45 [==============================] - 12s 273ms/step - loss: 0.0059 - acc: 0.9979 - val_loss: 2.9754 - val_acc: 0.5497
# Epoch 43/50
# 45/45 [==============================] - 12s 270ms/step - loss: 0.0088 - acc: 0.9979 - val_loss: 2.9103 - val_acc: 0.5710
# Epoch 44/50
# 45/45 [==============================] - 12s 274ms/step - loss: 0.0180 - acc: 0.9941 - val_loss: 2.3721 - val_acc: 0.5895
# Epoch 45/50
# 45/45 [==============================] - 12s 274ms/step - loss: 0.0101 - acc: 0.9972 - val_loss: 2.7133 - val_acc: 0.5994
# Epoch 46/50
# 45/45 [==============================] - 12s 276ms/step - loss: 0.0084 - acc: 0.9972 - val_loss: 3.0129 - val_acc: 0.5653
# Epoch 47/50
# 45/45 [==============================] - 12s 270ms/step - loss: 0.0178 - acc: 0.9931 - val_loss: 2.3740 - val_acc: 0.5781
# Epoch 48/50
# 45/45 [==============================] - 12s 270ms/step - loss: 0.0245 - acc: 0.9924 - val_loss: 2.7307 - val_acc: 0.5554
# Epoch 49/50
# 45/45 [==============================] - 12s 269ms/step - loss: 0.0306 - acc: 0.9910 - val_loss: 2.9311 - val_acc: 0.5440
# Epoch 50/50
# 45/45 [==============================] - 12s 272ms/step - loss: 0.0220 - acc: 0.9944 - val_loss: 3.1321 - val_acc: 0.5625
